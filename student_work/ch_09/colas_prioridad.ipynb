# %%
L = [-1,3,5,7,8,-23,-73]
L1 = [i ** 2 for i in L]
L1
# Out:
# [1, 9, 25, 49, 64, 529, 5329]

# %%
L.sort(key = lambda x:x**2)
L
# Out:
# [-1, 3, 5, 7, 8, -23, -73]

# %%
entradas = [(5,"A"),(9,"B"),(3,"B"),(7,"D")]
entradas.sort(key = lambda x:x[1])
entradas
# Out:
# [(5, 'A'), (9, 'B'), (3, 'B'), (7, 'D')]

# %%
#Definimos primeramente la cola de prioridad:

class cola_de_prioridad():
    def __init__(self):
        self.data = []
    
    def __len__(self):
        return len(self) == 0
    
    def add(self, k, v):
        self.data.append((k,v))

    def remove_min(self):
        CP.add(i,i**)
