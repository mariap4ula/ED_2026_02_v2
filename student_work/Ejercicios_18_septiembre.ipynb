# %%
from goodrich.ch09.unsorted_priority_queue import *

# %%
PQ = UnsortedPriorityQueue()

# %%
PQ.add(2, "María")
PQ.add(3.5, "Carlos")

# %%
len(PQ)
# Out:
# 2

# %%
class StackPQ():
    def __init__(self):
        self.data = UnsortedPrioryQueue()

    def push(self, e):
