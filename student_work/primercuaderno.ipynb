# %%
def sumar(a,b):
    return a + b

# %%
sumar(1, 7)
# Out:
# 8

# %%
from goodrich.ch06.array_stack import *

# %%
AS = ArrayStack()

# %%
AS.push?
# Out:
# Signature: AS.push(e)
# Docstring: Add element e to the top of the stack.
# File:      /workspaces/ED_2026_02_v2/goodrich/ch06/array_stack.py
# Type:      method
